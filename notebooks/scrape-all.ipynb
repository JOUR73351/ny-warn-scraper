# %%
# use the import keyword to import pandas, requests, and bs4 modules
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# assign the NY WARN notice url to a variable
url = "https://labor.ny.gov/app/warn/"

# %%
# define headers
headers = {'accept-encoding': 'deflate', 'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.129 Safari/537.36'}

# %%
# make a get request to the url using the requests library and assign the response to a variable called 'response'
response = requests.get(url, headers=headers)

# %%
# print out status code of response to confirm that your request worked
response.status_code
# Out:
# 200

# %%
# parse the response text using Beautiful Soup's html parser and assign output to a variable called 'soup'
# response.text
type(response.text)
# Out:
# str

# %%
# scrape the first table on the page and assign it to a variable called 'table'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
select = soup.find("select", id="warnYr")
select
# Out:
# <select id="warnYr" name="warnYr" onchange="pageRefresh()">
# <option selected="" value="2020">2020</option>
# <option value="2019">2019</option>
# <option value="2018">2018</option>
# <option value="2017">2017</option>
# <option value="2016">2016</option>
# <option value="2015">2015</option>
# <option value="2014">2014</option>
# <option value="2013">2013</option>
# <option value="2012">2012</option>
# </select>

# %%
#years = [option.text for option in select.find_all("option")]
years = ['2015']

# %%
# make an array called 'results'
results = []
control_numbers = set()
#loop through all years
for year in years:
    # form url for a specific year, eg https://labor.ny.gov/app/warn/default.asp?warnYr=2019
    year_url = f'{url}/default.asp?warnYr={year}'
    print(year_url)
    # make get request to url
    response = requests.get(year_url, headers=headers)
    # scrape the first table on the page and assign it to a variable called 'table'
    soup = BeautifulSoup(response.text, 'html.parser')
    table = soup.find("table")
    
    # get all the rows in the table — this is how many WARN notices there were in a specific year
    rows = table.find_all("tr")
    print(len(rows))
    
    # grab all rows from the table and assign to a variable called 'rows'
    # loop through the rows using a for loop. each row here is a company
    for row in rows:
        # grab the anchor tag (the link tag) in the row and then grab the href attribute from the tag
        a = row.find("a")['href']

        # concatenate the root url from above with this href attribute and assign to a variable called 'company_url'
        company_url = f'{url}{a}'
        print(company_url)

        # make a get request to the company url assign the response to a variable called 'company_response'
        company_response = requests.get(company_url, headers=headers)

        # parse the response text and assign output to a variable called 'company_soup'
        company_soup = BeautifulSoup(company_response.text, 'html.parser')

        # grab the first table on the page
        company_table = company_soup.find("table")

        

        # loop through all of the p tags
        paragraphs = company_table.find_all("p")
        paragraphs_iter = iter(paragraphs)
        skip = False
        for p in paragraphs_iter:
            # grab all of the values we want
            text = p.get_text('\n').replace('\xa0', '')
            if 'Date of Notice:' in text:
                notice_date = text.split(":")[1].strip().split('\n')[0].strip().replace(',', '').replace(';', '')
                #print(notice_date)
            elif 'Control Number:' in text:
                control_number = text.split(":")[1].strip()
                #print(control_number)
                if control_number in control_numbers:
                    print('repeated control number')
                    skip = True
                    break
                else:
                    control_numbers.add(control_number)
            elif 'Reason Stated for Filing:' in text:
                reason = text.split(":")[1].strip()
                #print(reason)
            elif 'Company:' in text:
                split_company = [x.strip() for x in text.split('\n')]
                if len(split_company) == 1:
                    #print("getting to 1")
                    next_text = next(paragraphs_iter)
                    #text = p.get_text('\n').replace('\xa0', '')
                    #print(next_text)
                    
                else: 
                    company = split_company[1]
                    address = ' '.join(split_company[2:])
#                 print(company)
#                 print(address)
#                 print('------------------------------------')
            elif 'County:' in text:
                county = f'{text.split(":")[1].strip().split("|")[0].strip()} County'
                #print(county)
            elif 'Phone:' in text:
                phone = text.split(":")[1].strip()
                #print(phone)
            elif 'Business Type:' in text:
                business_type = text.split(":")[1].strip().replace('Restaurants', 'Restaurant')
                #print(business_type)
            elif 'Number Affected:' in text:
                if '-----' in text:
                    affected = ''
                else:
                    affected = text.split(":")[1].strip().split(" ")[0].strip().split('\n')[0].strip()
                #print(affected)
            elif 'Total Employees:' in text:
                if '-----' in text:
                    total_employees = ''
                else:
                    total_employees = text.split(":")[1].strip().split(" ")[0].strip().replace(',', '')
                    #print(total_employees)
            elif 'Layoff Date:' in text:
                #print(text)
                layoff_date = text.split(":")[1].strip().split(" ")[0].strip().split(" ")[0].strip()
                #print(layoff_date)
            elif ('Reason for Dislocation:' in text):
                dislocation = text.split(":")[1].strip()
                #print(dislocation)
            elif ('Union:' in text):
                union = text.split(":")[1].strip()
                #print(union)
            elif ('Classification:' in text):
                classification = text.split(":")[1].strip()
                #print(classification)

        # store values in a result object
        if not skip:
            result = {
                'notice_date': notice_date,
                'reason': reason,
                'company': company,
                'address': address,
                'county': county,
                'phone': phone,
                'business_type': business_type,
                'affected': affected,
                'total_employees': total_employees,
                'layoff_date': layoff_date,
                'dislocation': dislocation,
                'union': union,
                'classification': classification
             }
            # append result object to results
            results.append(result)
        #break
print(len(results))
# Out:
# https://labor.ny.gov/app/warn//default.asp?warnYr=2015
# 434
# https://labor.ny.gov/app/warn/details.asp?id=5398
# https://labor.ny.gov/app/warn/details.asp?id=5393
# https://labor.ny.gov/app/warn/details.asp?id=5394
# https://labor.ny.gov/app/warn/details.asp?id=5396
# https://labor.ny.gov/app/warn/details.asp?id=5397
# https://labor.ny.gov/app/warn/details.asp?id=5391
# https://labor.ny.gov/app/warn/details.asp?id=5390
# https://labor.ny.gov/app/warn/details.asp?id=5389
# https://labor.ny.gov/app/warn/details.asp?id=5385
# https://labor.ny.gov/app/warn/details.asp?id=5387
# https://labor.ny.gov/app/warn/details.asp?id=5382
# https://labor.ny.gov/app/warn/details.asp?id=5383
# https://labor.ny.gov/app/warn/details.asp?id=5384
# https://labor.ny.gov/app/warn/details.asp?id=5381
# https://labor.ny.gov/app/warn/details.asp?id=5378
# https://labor.ny.gov/app/warn/details.asp?id=5379
# https://labor.ny.gov/app/warn/details.asp?id=5380
# https://labor.ny.gov/app/warn/details.asp?id=5375
# https://labor.ny.gov/app/warn/details.asp?id=5376
# https://labor.ny.gov/app/warn/details.asp?id=5372
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5373
# https://labor.ny.gov/app/warn/details.asp?id=5374
# https://labor.ny.gov/app/warn/details.asp?id=5371
# https://labor.ny.gov/app/warn/details.asp?id=5368
# https://labor.ny.gov/app/warn/details.asp?id=5369
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5364
# https://labor.ny.gov/app/warn/details.asp?id=5365
# https://labor.ny.gov/app/warn/details.asp?id=5366
# https://labor.ny.gov/app/warn/details.asp?id=5362
# https://labor.ny.gov/app/warn/details.asp?id=5363
# https://labor.ny.gov/app/warn/details.asp?id=5359
# https://labor.ny.gov/app/warn/details.asp?id=5360
# https://labor.ny.gov/app/warn/details.asp?id=5356
# https://labor.ny.gov/app/warn/details.asp?id=5357
# https://labor.ny.gov/app/warn/details.asp?id=5358
# https://labor.ny.gov/app/warn/details.asp?id=5355
# https://labor.ny.gov/app/warn/details.asp?id=5352
# https://labor.ny.gov/app/warn/details.asp?id=5353
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5351
# https://labor.ny.gov/app/warn/details.asp?id=5349
# https://labor.ny.gov/app/warn/details.asp?id=5350
# https://labor.ny.gov/app/warn/details.asp?id=5347
# https://labor.ny.gov/app/warn/details.asp?id=5348
# https://labor.ny.gov/app/warn/details.asp?id=5345
# https://labor.ny.gov/app/warn/details.asp?id=5341
# https://labor.ny.gov/app/warn/details.asp?id=5342
# https://labor.ny.gov/app/warn/details.asp?id=5344
# https://labor.ny.gov/app/warn/details.asp?id=5340
# https://labor.ny.gov/app/warn/details.asp?id=5339
# https://labor.ny.gov/app/warn/details.asp?id=5337
# https://labor.ny.gov/app/warn/details.asp?id=5338
# https://labor.ny.gov/app/warn/details.asp?id=5336
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5334
# https://labor.ny.gov/app/warn/details.asp?id=5335
# https://labor.ny.gov/app/warn/details.asp?id=5332
# https://labor.ny.gov/app/warn/details.asp?id=5333
# https://labor.ny.gov/app/warn/details.asp?id=5331
# https://labor.ny.gov/app/warn/details.asp?id=5327
# https://labor.ny.gov/app/warn/details.asp?id=5329
# https://labor.ny.gov/app/warn/details.asp?id=5325
# https://labor.ny.gov/app/warn/details.asp?id=5326
# https://labor.ny.gov/app/warn/details.asp?id=5324
# https://labor.ny.gov/app/warn/details.asp?id=5323
# https://labor.ny.gov/app/warn/details.asp?id=5320
# https://labor.ny.gov/app/warn/details.asp?id=5319
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5313
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5314
# https://labor.ny.gov/app/warn/details.asp?id=5315
# https://labor.ny.gov/app/warn/details.asp?id=5316
# https://labor.ny.gov/app/warn/details.asp?id=5317
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5308
# https://labor.ny.gov/app/warn/details.asp?id=5309
# https://labor.ny.gov/app/warn/details.asp?id=5310
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5311
# https://labor.ny.gov/app/warn/details.asp?id=5312
# https://labor.ny.gov/app/warn/details.asp?id=5307
# https://labor.ny.gov/app/warn/details.asp?id=5305
# https://labor.ny.gov/app/warn/details.asp?id=5306
# https://labor.ny.gov/app/warn/details.asp?id=5303
# https://labor.ny.gov/app/warn/details.asp?id=5304
# https://labor.ny.gov/app/warn/details.asp?id=5299
# https://labor.ny.gov/app/warn/details.asp?id=5300
# https://labor.ny.gov/app/warn/details.asp?id=5301
# https://labor.ny.gov/app/warn/details.asp?id=5297
# https://labor.ny.gov/app/warn/details.asp?id=5298
# https://labor.ny.gov/app/warn/details.asp?id=5296
# https://labor.ny.gov/app/warn/details.asp?id=5295
# https://labor.ny.gov/app/warn/details.asp?id=5292
# https://labor.ny.gov/app/warn/details.asp?id=5293
# https://labor.ny.gov/app/warn/details.asp?id=5294
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5290
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5291
# https://labor.ny.gov/app/warn/details.asp?id=5289
# https://labor.ny.gov/app/warn/details.asp?id=5288
# https://labor.ny.gov/app/warn/details.asp?id=5287
# https://labor.ny.gov/app/warn/details.asp?id=5286
# https://labor.ny.gov/app/warn/details.asp?id=5284
# https://labor.ny.gov/app/warn/details.asp?id=5282
# https://labor.ny.gov/app/warn/details.asp?id=5277
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5278
# https://labor.ny.gov/app/warn/details.asp?id=5279
# https://labor.ny.gov/app/warn/details.asp?id=5280
# https://labor.ny.gov/app/warn/details.asp?id=5274
# https://labor.ny.gov/app/warn/details.asp?id=5275
# https://labor.ny.gov/app/warn/details.asp?id=5276
# https://labor.ny.gov/app/warn/details.asp?id=5273
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5270
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5271
# https://labor.ny.gov/app/warn/details.asp?id=5272
# https://labor.ny.gov/app/warn/details.asp?id=5267
# https://labor.ny.gov/app/warn/details.asp?id=5269
# https://labor.ny.gov/app/warn/details.asp?id=5264
# https://labor.ny.gov/app/warn/details.asp?id=5265
# https://labor.ny.gov/app/warn/details.asp?id=5266
# https://labor.ny.gov/app/warn/details.asp?id=5261
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5262
# https://labor.ny.gov/app/warn/details.asp?id=5263
# https://labor.ny.gov/app/warn/details.asp?id=5260
# https://labor.ny.gov/app/warn/details.asp?id=5259
# https://labor.ny.gov/app/warn/details.asp?id=5257
# https://labor.ny.gov/app/warn/details.asp?id=5258
# https://labor.ny.gov/app/warn/details.asp?id=5254
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5255
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5256
# https://labor.ny.gov/app/warn/details.asp?id=5253
# https://labor.ny.gov/app/warn/details.asp?id=5252
# https://labor.ny.gov/app/warn/details.asp?id=5250
# https://labor.ny.gov/app/warn/details.asp?id=5248
# https://labor.ny.gov/app/warn/details.asp?id=5247
# https://labor.ny.gov/app/warn/details.asp?id=5243
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5244
# https://labor.ny.gov/app/warn/details.asp?id=5245
# https://labor.ny.gov/app/warn/details.asp?id=5246
# https://labor.ny.gov/app/warn/details.asp?id=5242
# https://labor.ny.gov/app/warn/details.asp?id=5238
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5239
# https://labor.ny.gov/app/warn/details.asp?id=5240
# https://labor.ny.gov/app/warn/details.asp?id=5241
# https://labor.ny.gov/app/warn/details.asp?id=5236
# https://labor.ny.gov/app/warn/details.asp?id=5237
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5235
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5228
# https://labor.ny.gov/app/warn/details.asp?id=5229
# https://labor.ny.gov/app/warn/details.asp?id=5230
# https://labor.ny.gov/app/warn/details.asp?id=5232
# https://labor.ny.gov/app/warn/details.asp?id=5233
# https://labor.ny.gov/app/warn/details.asp?id=5224
# https://labor.ny.gov/app/warn/details.asp?id=5225
# https://labor.ny.gov/app/warn/details.asp?id=5226
# https://labor.ny.gov/app/warn/details.asp?id=5227
# https://labor.ny.gov/app/warn/details.asp?id=5222
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5223
# https://labor.ny.gov/app/warn/details.asp?id=5220
# https://labor.ny.gov/app/warn/details.asp?id=5221
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5218
# https://labor.ny.gov/app/warn/details.asp?id=5214
# https://labor.ny.gov/app/warn/details.asp?id=5216
# https://labor.ny.gov/app/warn/details.asp?id=5213
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5206
# https://labor.ny.gov/app/warn/details.asp?id=5207
# https://labor.ny.gov/app/warn/details.asp?id=5209
# https://labor.ny.gov/app/warn/details.asp?id=5210
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5211
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5212
# https://labor.ny.gov/app/warn/details.asp?id=5205
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5200
# https://labor.ny.gov/app/warn/details.asp?id=5201
# https://labor.ny.gov/app/warn/details.asp?id=5202
# https://labor.ny.gov/app/warn/details.asp?id=5203
# https://labor.ny.gov/app/warn/details.asp?id=5196
# https://labor.ny.gov/app/warn/details.asp?id=5197
# https://labor.ny.gov/app/warn/details.asp?id=5198
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5199
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5190
# https://labor.ny.gov/app/warn/details.asp?id=5191
# https://labor.ny.gov/app/warn/details.asp?id=5192
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5193
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5194
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5195
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5188
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5189
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5187
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5185
# https://labor.ny.gov/app/warn/details.asp?id=5186
# https://labor.ny.gov/app/warn/details.asp?id=5182
# https://labor.ny.gov/app/warn/details.asp?id=5183
# https://labor.ny.gov/app/warn/details.asp?id=5184
# https://labor.ny.gov/app/warn/details.asp?id=5180
# https://labor.ny.gov/app/warn/details.asp?id=5181
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5176
# https://labor.ny.gov/app/warn/details.asp?id=5177
# https://labor.ny.gov/app/warn/details.asp?id=5178
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5179
# https://labor.ny.gov/app/warn/details.asp?id=5175
# https://labor.ny.gov/app/warn/details.asp?id=5174
# https://labor.ny.gov/app/warn/details.asp?id=5172
# https://labor.ny.gov/app/warn/details.asp?id=5173
# https://labor.ny.gov/app/warn/details.asp?id=5171
# https://labor.ny.gov/app/warn/details.asp?id=5169
# https://labor.ny.gov/app/warn/details.asp?id=5170
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5168
# https://labor.ny.gov/app/warn/details.asp?id=5164
# https://labor.ny.gov/app/warn/details.asp?id=5165
# https://labor.ny.gov/app/warn/details.asp?id=5166
# https://labor.ny.gov/app/warn/details.asp?id=5163
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5161
# https://labor.ny.gov/app/warn/details.asp?id=5162
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5159
# https://labor.ny.gov/app/warn/details.asp?id=5160
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5156
# https://labor.ny.gov/app/warn/details.asp?id=5157
# https://labor.ny.gov/app/warn/details.asp?id=5153
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5154
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5155
# https://labor.ny.gov/app/warn/details.asp?id=5150
# https://labor.ny.gov/app/warn/details.asp?id=5151
# https://labor.ny.gov/app/warn/details.asp?id=5152
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5149
# https://labor.ny.gov/app/warn/details.asp?id=5144
# https://labor.ny.gov/app/warn/details.asp?id=5145
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5146
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5148
# https://labor.ny.gov/app/warn/details.asp?id=5143
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5141
# https://labor.ny.gov/app/warn/details.asp?id=5142
# https://labor.ny.gov/app/warn/details.asp?id=5140
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5139
# https://labor.ny.gov/app/warn/details.asp?id=5137
# https://labor.ny.gov/app/warn/details.asp?id=5138
# https://labor.ny.gov/app/warn/details.asp?id=5132
# https://labor.ny.gov/app/warn/details.asp?id=5133
# https://labor.ny.gov/app/warn/details.asp?id=5134
# https://labor.ny.gov/app/warn/details.asp?id=5135
# https://labor.ny.gov/app/warn/details.asp?id=5136
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5130
# https://labor.ny.gov/app/warn/details.asp?id=5131
# https://labor.ny.gov/app/warn/details.asp?id=5125
# https://labor.ny.gov/app/warn/details.asp?id=5126
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5127
# https://labor.ny.gov/app/warn/details.asp?id=5128
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5129
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5120
# https://labor.ny.gov/app/warn/details.asp?id=5121
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5122
# https://labor.ny.gov/app/warn/details.asp?id=5123
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5124
# https://labor.ny.gov/app/warn/details.asp?id=5118
# https://labor.ny.gov/app/warn/details.asp?id=5119
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5114
# https://labor.ny.gov/app/warn/details.asp?id=5115
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5116
# https://labor.ny.gov/app/warn/details.asp?id=5117
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5110
# https://labor.ny.gov/app/warn/details.asp?id=5111
# https://labor.ny.gov/app/warn/details.asp?id=5112
# https://labor.ny.gov/app/warn/details.asp?id=5113
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5107
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5108
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5105
# https://labor.ny.gov/app/warn/details.asp?id=5106
# https://labor.ny.gov/app/warn/details.asp?id=5099
# https://labor.ny.gov/app/warn/details.asp?id=5100
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5101
# https://labor.ny.gov/app/warn/details.asp?id=5102
# https://labor.ny.gov/app/warn/details.asp?id=5103
# https://labor.ny.gov/app/warn/details.asp?id=5096
# https://labor.ny.gov/app/warn/details.asp?id=5098
# https://labor.ny.gov/app/warn/details.asp?id=5094
# https://labor.ny.gov/app/warn/details.asp?id=5095
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5093
# https://labor.ny.gov/app/warn/details.asp?id=5091
# https://labor.ny.gov/app/warn/details.asp?id=5092
# https://labor.ny.gov/app/warn/details.asp?id=5088
# https://labor.ny.gov/app/warn/details.asp?id=5089
# https://labor.ny.gov/app/warn/details.asp?id=5090
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5086
# https://labor.ny.gov/app/warn/details.asp?id=5087
# https://labor.ny.gov/app/warn/details.asp?id=5084
# https://labor.ny.gov/app/warn/details.asp?id=5085
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5082
# https://labor.ny.gov/app/warn/details.asp?id=5083
# https://labor.ny.gov/app/warn/details.asp?id=5080
# https://labor.ny.gov/app/warn/details.asp?id=5076
# https://labor.ny.gov/app/warn/details.asp?id=5077
# https://labor.ny.gov/app/warn/details.asp?id=5078
# https://labor.ny.gov/app/warn/details.asp?id=5072
# https://labor.ny.gov/app/warn/details.asp?id=5073
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5075
# https://labor.ny.gov/app/warn/details.asp?id=5070
# https://labor.ny.gov/app/warn/details.asp?id=5071
# https://labor.ny.gov/app/warn/details.asp?id=5066
# https://labor.ny.gov/app/warn/details.asp?id=5067
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5068
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5069
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5061
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5062
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5063
# https://labor.ny.gov/app/warn/details.asp?id=5064
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5065
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5059
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5060
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5056
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5057
# https://labor.ny.gov/app/warn/details.asp?id=5058
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5049
# https://labor.ny.gov/app/warn/details.asp?id=5050
# https://labor.ny.gov/app/warn/details.asp?id=5051
# https://labor.ny.gov/app/warn/details.asp?id=5052
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5053
# https://labor.ny.gov/app/warn/details.asp?id=5054
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5046
# https://labor.ny.gov/app/warn/details.asp?id=5047
# https://labor.ny.gov/app/warn/details.asp?id=5048
# https://labor.ny.gov/app/warn/details.asp?id=5041
# https://labor.ny.gov/app/warn/details.asp?id=5042
# https://labor.ny.gov/app/warn/details.asp?id=5043
# https://labor.ny.gov/app/warn/details.asp?id=5044
# https://labor.ny.gov/app/warn/details.asp?id=5045
# https://labor.ny.gov/app/warn/details.asp?id=5038
# https://labor.ny.gov/app/warn/details.asp?id=5039
# https://labor.ny.gov/app/warn/details.asp?id=5040
# https://labor.ny.gov/app/warn/details.asp?id=5037
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5034
# https://labor.ny.gov/app/warn/details.asp?id=5035
# https://labor.ny.gov/app/warn/details.asp?id=5036
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5030
# https://labor.ny.gov/app/warn/details.asp?id=5031
# https://labor.ny.gov/app/warn/details.asp?id=5032
# https://labor.ny.gov/app/warn/details.asp?id=5033
# https://labor.ny.gov/app/warn/details.asp?id=5023
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5024
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5025
# https://labor.ny.gov/app/warn/details.asp?id=5026
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5022
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5019
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5020
# https://labor.ny.gov/app/warn/details.asp?id=5021
# https://labor.ny.gov/app/warn/details.asp?id=5015
# https://labor.ny.gov/app/warn/details.asp?id=5016
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5017
# https://labor.ny.gov/app/warn/details.asp?id=5018
# https://labor.ny.gov/app/warn/details.asp?id=5011
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5012
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5010
# https://labor.ny.gov/app/warn/details.asp?id=5007
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5008
# https://labor.ny.gov/app/warn/details.asp?id=5009
# https://labor.ny.gov/app/warn/details.asp?id=5002
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=5003
# https://labor.ny.gov/app/warn/details.asp?id=5004
# https://labor.ny.gov/app/warn/details.asp?id=5005
# https://labor.ny.gov/app/warn/details.asp?id=5006
# https://labor.ny.gov/app/warn/details.asp?id=5000
# https://labor.ny.gov/app/warn/details.asp?id=5001
# https://labor.ny.gov/app/warn/details.asp?id=4992
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4993
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4994
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4995
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4996
# https://labor.ny.gov/app/warn/details.asp?id=4997
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4998
# https://labor.ny.gov/app/warn/details.asp?id=4999
# https://labor.ny.gov/app/warn/details.asp?id=4991
# https://labor.ny.gov/app/warn/details.asp?id=4988
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4989
# https://labor.ny.gov/app/warn/details.asp?id=4990
# https://labor.ny.gov/app/warn/details.asp?id=4986
# https://labor.ny.gov/app/warn/details.asp?id=4983
# https://labor.ny.gov/app/warn/details.asp?id=4984
# https://labor.ny.gov/app/warn/details.asp?id=4985
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4982
# https://labor.ny.gov/app/warn/details.asp?id=4981
# https://labor.ny.gov/app/warn/details.asp?id=4979
# https://labor.ny.gov/app/warn/details.asp?id=4980
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4974
# https://labor.ny.gov/app/warn/details.asp?id=4975
# https://labor.ny.gov/app/warn/details.asp?id=4976
# https://labor.ny.gov/app/warn/details.asp?id=4977
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4978
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4973
# https://labor.ny.gov/app/warn/details.asp?id=4971
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4972
# https://labor.ny.gov/app/warn/details.asp?id=4969
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4970
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4967
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4968
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4963
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4965
# https://labor.ny.gov/app/warn/details.asp?id=4966
# https://labor.ny.gov/app/warn/details.asp?id=4961
# https://labor.ny.gov/app/warn/details.asp?id=4962
# https://labor.ny.gov/app/warn/details.asp?id=4956
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4957
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4958
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4959
# https://labor.ny.gov/app/warn/details.asp?id=4960
# https://labor.ny.gov/app/warn/details.asp?id=4951
# https://labor.ny.gov/app/warn/details.asp?id=4952
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4949
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4950
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4947
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4948
# https://labor.ny.gov/app/warn/details.asp?id=4946
# https://labor.ny.gov/app/warn/details.asp?id=4944
# https://labor.ny.gov/app/warn/details.asp?id=4945
# https://labor.ny.gov/app/warn/details.asp?id=4940
# https://labor.ny.gov/app/warn/details.asp?id=4941
# https://labor.ny.gov/app/warn/details.asp?id=4942
# https://labor.ny.gov/app/warn/details.asp?id=4943
# https://labor.ny.gov/app/warn/details.asp?id=4938
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4939
# https://labor.ny.gov/app/warn/details.asp?id=4937
# https://labor.ny.gov/app/warn/details.asp?id=4936
# https://labor.ny.gov/app/warn/details.asp?id=4932
# https://labor.ny.gov/app/warn/details.asp?id=4933
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4934
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4935
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4928
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4930
# https://labor.ny.gov/app/warn/details.asp?id=4931
# https://labor.ny.gov/app/warn/details.asp?id=4925
# https://labor.ny.gov/app/warn/details.asp?id=4926
# https://labor.ny.gov/app/warn/details.asp?id=4927
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4923
# https://labor.ny.gov/app/warn/details.asp?id=4924
# https://labor.ny.gov/app/warn/details.asp?id=4921
# https://labor.ny.gov/app/warn/details.asp?id=4922
# repeated control number
# https://labor.ny.gov/app/warn/details.asp?id=4918
# https://labor.ny.gov/app/warn/details.asp?id=4919
# https://labor.ny.gov/app/warn/details.asp?id=4916
# https://labor.ny.gov/app/warn/details.asp?id=4917
# https://labor.ny.gov/app/warn/details.asp?id=4912
# https://labor.ny.gov/app/warn/details.asp?id=4913
# https://labor.ny.gov/app/warn/details.asp?id=4914
# repeated control number
# 313

# %%
# wrap results in a dataframe
df = pd.DataFrame(results)

# %%
pd.options.display.max_rows = 1237
df['layoff_date'].unique()
# Out:
# array(['3/19/2020', '5/29/2020', '6/1/2020', '3/18/2020', '3/30/2020',
#        '3/12/2020', '3/27/2020', '4/24/2020', '4/16/2020', '3/20/2020',
#        '4/3/2020', '6/30/2020', '4/23/2020', '3/16/2020', '3/17/2020',
#        '4/4/2020', '4/8/2020', '4/22/2020', '3/24/2020', '4/13/2020',
#        '4/10/2020', 'Furloughs', '3/22/2020', '3/23/2020', 'Separation',
#        '3/29/2020', '3/25/2020', 'Separations', '32', 'Layoffs',
#        '7/30/2020', '4/25/2020', '4/1/2020', '7/19/2020', '6/19/2020',
#        '7/3/2020', '4/20/2020', '3/31/2020', '4/14/2020', '3/28/2020',
#        '72', 'The', '51', '86', '88', '37', 'Nine', '4/6/2020',
#        '4/30/2020', '(21)', '(27)', 'March', '30', '18', '14', 'Seven',
#        '4/2/2020', '3/21/2020', '356', '34', '330', '69', '52', '87',
#        '81', '-----', '4/7/2020', '48', '3/15/2020', '3/26/2020',
#        '3/10/2020', '4/12/2020', '362', '5/1/2020', '3/13/2020',
#        '4/5/2020', '3/19/2020,', '7/12/2020', '4/11/2020', '6/26/2020',
#        '4/1/2020,', '7/1/2020', '287', 'A', '146', '3/14/2020',
#        '3/6/2020', 'May', '6/21/2020', '6/24/2020', '2/23/2020',
#        '3/11/2020', 'Close', '', '6/12/2020', 'June', 'First',
#        '6/17/2020', 'To', '7/31/2020', '6/3/2020', '6/14/2020',
#        '5/31/2020', 'December', 'Employee', 'Employment', '2/29/2020',
#        '5/22/2020', 'April', 'Separtions', 'Employees', '4/27/2020',
#        "Macy's", 'Beginning', '1/12/2020'], dtype=object)

# %%
# output dataframe to a csv
df.to_csv('../data/warn.csv', index=False)
